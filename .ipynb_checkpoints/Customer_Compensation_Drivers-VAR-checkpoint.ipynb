# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
import json

# %% [markdown]
# ## 1. Prepare time series data

# %%
# Load data
df = pd.read_excel("dataset.xlsx", sheet_name='Modified Gross CPO Data')

# Ensure date is datetime
df['date'] = pd.to_datetime(df['date'])

# Sort by time
df = df.sort_values('date')
df = df.set_index('date')
df.head()
# Out:
#             Policy change 1  Policy change 2  Automation (%)  Good Orders  \
# date
# 2024-09-30                1                0        0.281982    1004435.0
# 2024-10-07                1                0        0.290226    1106380.5
# 2024-10-14                1                0        0.294271    1130292.0
# 2024-10-21                1                0        0.293731    1142913.5
# 2024-10-28                1                0        0.311397    1193250.0
#
#             Bad Orders  Undelivered Orders  Restaurant Count  \
# date
# 2024-09-30     18360.0              2912.0           21950.0
# 2024-10-07     21589.0              2612.0           22229.0
# 2024-10-14     22621.5              2544.5           26323.0
# 2024-10-21     20269.0              2508.0           26851.0
# 2024-10-28     24276.0              2731.0           27113.0
#
#             Avg. End To End (mins)  % End To End > 45 mins  \
# date
# 2024-09-30                   16.10                  0.0665
# 2024-10-07                   16.10                  0.0660
# 2024-10-14                   16.15                  0.0675
# 2024-10-21                   15.60                  0.0575
# 2024-10-28                   16.05                  0.0660
#
#             % End To End > 60 mins  ...  % Long Assignment Orders  \
# date                                ...
# 2024-09-30                   0.018  ...                    0.0080
# 2024-10-07                   0.018  ...                    0.0085
# 2024-10-14                   0.019  ...                    0.0090
# 2024-10-21                   0.014  ...                    0.0055
# 2024-10-28                   0.018  ...                    0.0080
#
#             % HQ Orders  Total Contact Propensity  \
# date
# 2024-09-30       0.4100                    0.0425
# 2024-10-07       0.4125                    0.0395
# 2024-10-14       0.4125                    0.0405
# 2024-10-21       0.4135                    0.0380
# 2024-10-28       0.4105                    0.0395
#
#             Automation Contact Propensity  Advisor Contact Propensity  \
# date
# 2024-09-30                         0.0210                      0.0215
# 2024-10-07                         0.0195                      0.0200
# 2024-10-14                         0.0205                      0.0200
# 2024-10-21                         0.0190                      0.0190
# 2024-10-28                         0.0215                      0.0180
#
#             Customer Contact Propensity  Customer Compensation Propensity  \
# date
# 2024-09-30                       0.0400                            0.0265
# 2024-10-07                       0.0370                            0.0240
# 2024-10-14                       0.0380                            0.0245
# 2024-10-21                       0.0355                            0.0230
# 2024-10-28                       0.0370                            0.0235
#
#             Decline Rate  Gross CPE  Gross CPO
# date
# 2024-09-30        0.0780      4.335     0.2395
# 2024-10-07        0.1025      4.240     0.2145
# 2024-10-14        0.1150      4.145     0.2125
# 2024-10-21        0.1150      4.095     0.1980
# 2024-10-28        0.1120      3.775     0.1885
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Policy change 1', 'Policy change 2', 'Automation (%)', 'Good Orders',
#        'Bad Orders', 'Undelivered Orders', 'Restaurant Count',
#        'Avg. End To End (mins)', '% End To End > 45 mins',
#        '% End To End > 60 mins', 'Avg. End To End excl McDonald's (mins)',
#        'Avg. Placed to Delivered (mins)',
#        'Avg. Customer Radius to Delivered (mins)',
#        '% Bad + Undelivered Orders', '% Bad Orders', '% McD Recook', 'On Time',
#        'Late', 'Early', 'Very Late', 'Very Early',
#        'Post-order customer ETA accuracy (+/- 5 min)',
#        '% Long Assignment Orders', '% HQ Orders', 'Total Contact Propensity',
#        'Automation Contact Propensity', 'Advisor Contact Propensity',
#        'Customer Contact Propensity', 'Customer Compensation Propensity',
#        'Decline Rate', 'Gross CPE', 'Gross CPO'],
#       dtype='object')

# %% [markdown]
# ## 2. Visual check for stationarity

# %%
df['Gross CPO'].plot(figsize=(12,4), title="Gross CPO (Weekly)")
plt.show()

# %% [markdown]
# __Findings__:
# * __Phase 1 - Oct 2024 to Mar 2025__: Relatively stable around 0.20–0.22
# * __Phase 2 - Apr 2025 to mid-Jun 2025__: Slight dip to ~0.18 then slow rise
# * __Phase 3 - Late Jun 2025 onward__: Sharp upward trend jumping significantly above 0.28
#
# The upward shift is a level change.
# The mean before June and after June are objectively different.
#
# This violates the assumption of stationarity.

# %% [markdown]
# ## 3. Feature selection for temporal modelling

# %% [markdown]
# ### Data Leakage / Target Leakage
# Exclude all post-order contact, compensation, and ETA accuracy metrics:
# * _Total Contact Propensity_
# * _Automation Contact Propensity_
# * _Advisor Contact Propensity_
# * _Customer Contact Propensity_
# * _Customer Compensation Propensity_
# * _Decline Rate_
# * _Gross CPE_
# * _Gross CPO_ (target itself)
#
# Exclude post-order timeliness classifications:
# * _On Time_
# * _Late_
# * _Early_
# * _Very Late_
# * _Very Early_
# * _Post-order customer ETA accuracy (+/- 5 min)_
#
# These metrics are effects, not causes.

# %% [markdown]
# ### Duplication/Perfect Correlation
#
# Exclude _% Bad Orders_ and _Undelivered Orders_
# * If already represented inside _% Bad + Undelivered Orders_.
# * Causes multicollinearity.
#
# Exclude _Avg. End to End_ and _Avg. Placed to Delivered_
# * Duplicates - both describe the same duration.
#
# Exclude metrics that are transformations of others:
# * _% End To End > 45 mins_
# * _% End To End > 60 mins_
# * _Avg. End To End excl Brand 1_
#
# These are nonlinear partitions of overall speed metrics. Keep one clean lag-time signal (e.g., _Avg. End-to-End_) to avoid clutter.
#
# Exclude _% Brand 1 Recook_
# * If Brand 1 volume is small, this injects noise and collinearity with Bad Orders.

# %% [markdown]
# ### Circularity
#
# _Good Orders_
# * Gross CPO = compensation / good orders
# * Including _Good Orders_ as a driver creates mathematical dependence. This is a bad modelling practice.

# %% [markdown]
# ### True Drivers

# %%
drivers = [
"Policy change 1", "Policy change 2", "Automation (%)", "Bad Orders", "Undelivered Orders", "Restaurant Count", 
    "Avg. Customer Radius to Delivered (mins)", "% Long Assignment Orders", "% HQ Orders", "Avg. End To End (mins)"
]

# choose Bad Orders or % Bad + Undelivered
# choose Undelivered Orders if not using the combined % metric

ts_df = df[['Gross CPO'] + drivers]
ts_df.head()
# Out:
#             Gross CPO  Policy change 1  Policy change 2  Automation (%)  \
# date
# 2024-09-30     0.2395                1                0        0.281982
# 2024-10-07     0.2145                1                0        0.290226
# 2024-10-14     0.2125                1                0        0.294271
# 2024-10-21     0.1980                1                0        0.293731
# 2024-10-28     0.1885                1                0        0.311397
#
#             Bad Orders  Undelivered Orders  Restaurant Count  \
# date
# 2024-09-30     18360.0              2912.0           21950.0
# 2024-10-07     21589.0              2612.0           22229.0
# 2024-10-14     22621.5              2544.5           26323.0
# 2024-10-21     20269.0              2508.0           26851.0
# 2024-10-28     24276.0              2731.0           27113.0
#
#             Avg. Customer Radius to Delivered (mins)  \
# date
# 2024-09-30                                      0.95
# 2024-10-07                                      0.95
# 2024-10-14                                      0.95
# 2024-10-21                                      0.95
# 2024-10-28                                      0.95
#
#             % Long Assignment Orders  % HQ Orders  Avg. End To End (mins)
# date
# 2024-09-30                    0.0080       0.4100                   16.10
# 2024-10-07                    0.0085       0.4125                   16.10
# 2024-10-14                    0.0090       0.4125                   16.15
# 2024-10-21                    0.0055       0.4135                   15.60
# 2024-10-28                    0.0080       0.4105                   16.05

# %% [markdown]
# ## 4. Check stationarity using ADF test

# %%
from statsmodels.tsa.stattools import adfuller

for col in ts_df.columns:
    result = adfuller(ts_df[col].dropna())
    print(col, result[1])
# Out:
# Gross CPO 0.9197490624196991
# Policy change 1 0.8332377238401021
# Policy change 2 0.0062215008269728995
# Automation (%) 0.7901211148007954
# Bad Orders 0.8395860705146461
# Undelivered Orders 0.00036148575773852355
# Restaurant Count 5.565389420346373e-12
# Avg. Customer Radius to Delivered (mins) 0.017523588418377554
# % Long Assignment Orders 0.5563882127565347
# % HQ Orders 0.18274337186456951
# Avg. End To End (mins) 0.35623232955843465
# c:\Users\haerb\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:958: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2

# %% [markdown]
# * p-value < 0.05 → stationary
# * p-value ≥ 0.05 → difference column

# %%
ts_df_diff = ts_df.diff().dropna()

# %% [markdown]
# ## 5. Fit a VAR model (multivariate AR model)

# %%
model = VAR(ts_df_diff)

# Select optimal lag length
lag_order = model.select_order(maxlags=3)
print(lag_order.summary())

best_lag = lag_order.selected_orders['aic']
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -23.09     -22.69*   9.368e-11      -22.94
# 1      -23.89      -19.07   4.575e-11      -22.02
# 2      -24.45      -15.22   4.380e-11      -20.88
# 3     -31.22*      -17.57  2.710e-13*     -25.94*
# -------------------------------------------------
# c:\Users\haerb\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   self._init_dates(dates, freq)

# %%
var_model = model.fit(best_lag)
print(var_model.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 07, Dec, 2025
# Time:                     13:03:58
# --------------------------------------------------------------------
# No. of Equations:         11.0000    BIC:                   -17.5722
# Nobs:                     55.0000    HQIC:                  -25.9436
# Log likelihood:           374.149    FPE:                2.70954e-13
# AIC:                     -31.2221    Det(Omega_mle):     1.36018e-15
# --------------------------------------------------------------------
# Results for equation Gross CPO
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                               0.000680         0.003286            0.207           0.836
# L1.Gross CPO                                        0.248669         0.271626            0.915           0.360
# L1.Policy change 1                                 -0.052364         0.018975           -2.760           0.006
# L1.Policy change 2                                 -0.013905         0.018803           -0.740           0.460
# L1.Automation (%)                                   0.570546         0.558033            1.022           0.307
# L1.Bad Orders                                      -0.000000         0.000002           -0.023           0.982
# L1.Undelivered Orders                               0.000022         0.000017            1.261           0.207
# L1.Restaurant Count                                 0.000015         0.000028            0.537           0.591
# L1.Avg. Customer Radius to Delivered (mins)         0.063684         0.080598            0.790           0.429
# L1.% Long Assignment Orders                         2.038527         2.681363            0.760           0.447
# L1.% HQ Orders                                      0.172392         1.231953            0.140           0.889
# L1.Avg. End To End (mins)                          -0.029993         0.020950           -1.432           0.152
# L2.Gross CPO                                       -0.243164         0.344882           -0.705           0.481
# L2.Policy change 1                                  0.004149         0.029705            0.140           0.889
# L2.Policy change 2                                  0.042009         0.018240            2.303           0.021
# L2.Automation (%)                                   0.585158         0.643908            0.909           0.363
# L2.Bad Orders                                       0.000000         0.000001            0.230           0.818
# L2.Undelivered Orders                              -0.000015         0.000017           -0.899           0.369
# L2.Restaurant Count                                -0.000010         0.000006           -1.523           0.128
# L2.Avg. Customer Radius to Delivered (mins)         0.076791         0.086975            0.883           0.377
# L2.% Long Assignment Orders                         0.339928         2.403793            0.141           0.888
# L2.% HQ Orders                                      0.434088         1.297584            0.335           0.738
# L2.Avg. End To End (mins)                          -0.004133         0.020130           -0.205           0.837
# L3.Gross CPO                                       -0.408858         0.263246           -1.553           0.120
# L3.Policy change 1                                 -0.017697         0.040805           -0.434           0.665
# L3.Policy change 2                                  0.000900         0.020985            0.043           0.966
# L3.Automation (%)                                  -0.846944         0.618051           -1.370           0.171
# L3.Bad Orders                                       0.000001         0.000001            0.903           0.367
# L3.Undelivered Orders                              -0.000025         0.000017           -1.520           0.128
# L3.Restaurant Count                                -0.000001         0.000005           -0.277           0.782
# L3.Avg. Customer Radius to Delivered (mins)        -0.001236         0.124385           -0.010           0.992
# L3.% Long Assignment Orders                        -0.106550         2.356557           -0.045           0.964
# L3.% HQ Orders                                      0.220507         1.055029            0.209           0.834
# L3.Avg. End To End (mins)                           0.011773         0.017900            0.658           0.511
# ==============================================================================================================
#
# Results for equation Policy change 1
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                               0.023238         0.039919            0.582           0.560
# L1.Gross CPO                                       -2.980941         3.299989           -0.903           0.366
# L1.Policy change 1                                 -0.292109         0.230530           -1.267           0.205
# L1.Policy change 2                                  0.024583         0.228439            0.108           0.914
# L1.Automation (%)                                   3.555803         6.779558            0.524           0.600
# L1.Bad Orders                                      -0.000017         0.000019           -0.877           0.381
# L1.Undelivered Orders                              -0.000149         0.000209           -0.713           0.476
# L1.Restaurant Count                                -0.000053         0.000344           -0.155           0.877
# L1.Avg. Customer Radius to Delivered (mins)         0.746407         0.979183            0.762           0.446
# L1.% Long Assignment Orders                        21.768911        32.575941            0.668           0.504
# L1.% HQ Orders                                     16.315680        14.967024            1.090           0.276
# L1.Avg. End To End (mins)                           0.220633         0.254526            0.867           0.386
# L2.Gross CPO                                        3.256615         4.189980            0.777           0.437
# L2.Policy change 1                                 -0.199292         0.360890           -0.552           0.581
# L2.Policy change 2                                  0.057048         0.221594            0.257           0.797
# L2.Automation (%)                                   2.134983         7.822858            0.273           0.785
# L2.Bad Orders                                       0.000001         0.000015            0.097           0.923
# L2.Undelivered Orders                              -0.000230         0.000205           -1.117           0.264
# L2.Restaurant Count                                -0.000024         0.000077           -0.318           0.750
# L2.Avg. Customer Radius to Delivered (mins)         0.371917         1.056663            0.352           0.725
# L2.% Long Assignment Orders                       -70.985839        29.203736           -2.431           0.015
# L2.% HQ Orders                                      7.315466        15.764373            0.464           0.643
# L2.Avg. End To End (mins)                           0.473364         0.244562            1.936           0.053
# L3.Gross CPO                                       -4.590771         3.198187           -1.435           0.151
# L3.Policy change 1                                  0.503597         0.495747            1.016           0.310
# L3.Policy change 2                                 -0.033680         0.254946           -0.132           0.895
# L3.Automation (%)                                 -11.565048         7.508719           -1.540           0.124
# L3.Bad Orders                                       0.000014         0.000013            1.005           0.315
# L3.Undelivered Orders                              -0.000436         0.000202           -2.154           0.031
# L3.Restaurant Count                                -0.000010         0.000058           -0.169           0.866
# L3.Avg. Customer Radius to Delivered (mins)        -0.620628         1.511157           -0.411           0.681
# L3.% Long Assignment Orders                       -44.165621        28.629867           -1.543           0.123
# L3.% HQ Orders                                      7.233688        12.817570            0.564           0.573
# L3.Avg. End To End (mins)                           0.352702         0.217462            1.622           0.105
# ==============================================================================================================
#
# Results for equation Policy change 2
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                              -0.011834         0.005385           -2.198           0.028
# L1.Gross CPO                                       -1.264378         0.445157           -2.840           0.005
# L1.Policy change 1                                 -0.022991         0.031098           -0.739           0.460
# L1.Policy change 2                                 -0.129035         0.030816           -4.187           0.000
# L1.Automation (%)                                  -0.540130         0.914538           -0.591           0.555
# L1.Bad Orders                                       0.000003         0.000003            1.183           0.237
# L1.Undelivered Orders                               0.000047         0.000028            1.681           0.093
# L1.Restaurant Count                                -0.000137         0.000046           -2.941           0.003
# L1.Avg. Customer Radius to Delivered (mins)        -0.050218         0.132088           -0.380           0.704
# L1.% Long Assignment Orders                         0.838023         4.394380            0.191           0.849
# L1.% HQ Orders                                      1.857880         2.018999            0.920           0.357
# L1.Avg. End To End (mins)                          -0.018428         0.034335           -0.537           0.591
# L2.Gross CPO                                        0.062340         0.565214            0.110           0.912
# L2.Policy change 1                                 -0.030910         0.048683           -0.635           0.525
# L2.Policy change 2                                 -0.033881         0.029892           -1.133           0.257
# L2.Automation (%)                                   1.539246         1.055276            1.459           0.145
# L2.Bad Orders                                       0.000001         0.000002            0.459           0.646
# L2.Undelivered Orders                               0.000067         0.000028            2.412           0.016
# L2.Restaurant Count                                -0.000008         0.000010           -0.755           0.450
# L2.Avg. Customer Radius to Delivered (mins)         0.004297         0.142540            0.030           0.976
# L2.% Long Assignment Orders                        -3.267589         3.939481           -0.829           0.407
# L2.% HQ Orders                                      2.020906         2.126558            0.950           0.342
# L2.Avg. End To End (mins)                          -0.000499         0.032990           -0.015           0.988
# L3.Gross CPO                                       -0.151653         0.431424           -0.352           0.725
# L3.Policy change 1                                 -0.041036         0.066874           -0.614           0.539
# L3.Policy change 2                                  0.047349         0.034391            1.377           0.169
# L3.Automation (%)                                   0.917580         1.012900            0.906           0.365
# L3.Bad Orders                                       0.000003         0.000002            1.422           0.155
# L3.Undelivered Orders                              -0.000006         0.000027           -0.202           0.840
# L3.Restaurant Count                                 0.000248         0.000008           31.718           0.000
# L3.Avg. Customer Radius to Delivered (mins)        -0.078940         0.203850           -0.387           0.699
# L3.% Long Assignment Orders                        -2.359841         3.862068           -0.611           0.541
# L3.% HQ Orders                                      0.655736         1.729045            0.379           0.705
# L3.Avg. End To End (mins)                          -0.016997         0.029335           -0.579           0.562
# ==============================================================================================================
#
# Results for equation Automation (%)
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                               0.002631         0.001667            1.578           0.115
# L1.Gross CPO                                        0.081769         0.137847            0.593           0.553
# L1.Policy change 1                                 -0.016056         0.009630           -1.667           0.095
# L1.Policy change 2                                  0.007941         0.009542            0.832           0.405
# L1.Automation (%)                                  -0.254351         0.283196           -0.898           0.369
# L1.Bad Orders                                      -0.000001         0.000001           -0.796           0.426
# L1.Undelivered Orders                               0.000003         0.000009            0.372           0.710
# L1.Restaurant Count                                -0.000022         0.000014           -1.511           0.131
# L1.Avg. Customer Radius to Delivered (mins)         0.033282         0.040903            0.814           0.416
# L1.% Long Assignment Orders                        -1.402869         1.360765           -1.031           0.303
# L1.% HQ Orders                                     -0.500178         0.625204           -0.800           0.424
# L1.Avg. End To End (mins)                           0.009284         0.010632            0.873           0.383
# L2.Gross CPO                                       -0.028484         0.175024           -0.163           0.871
# L2.Policy change 1                                 -0.016543         0.015075           -1.097           0.272
# L2.Policy change 2                                  0.012104         0.009256            1.308           0.191
# L2.Automation (%)                                  -0.762469         0.326777           -2.333           0.020
# L2.Bad Orders                                      -0.000000         0.000001           -0.801           0.423
# L2.Undelivered Orders                              -0.000002         0.000009           -0.242           0.808
# L2.Restaurant Count                                 0.000007         0.000003            2.308           0.021
# L2.Avg. Customer Radius to Delivered (mins)         0.011953         0.044139            0.271           0.787
# L2.% Long Assignment Orders                         1.071977         1.219901            0.879           0.380
# L2.% HQ Orders                                     -1.078284         0.658511           -1.637           0.102
# L2.Avg. End To End (mins)                          -0.005272         0.010216           -0.516           0.606
# L3.Gross CPO                                       -0.017568         0.133595           -0.132           0.895
# L3.Policy change 1                                 -0.027502         0.020708           -1.328           0.184
# L3.Policy change 2                                 -0.004672         0.010650           -0.439           0.661
# L3.Automation (%)                                  -0.001687         0.313655           -0.005           0.996
# L3.Bad Orders                                      -0.000000         0.000001           -0.380           0.704
# L3.Undelivered Orders                               0.000005         0.000008            0.595           0.552
# L3.Restaurant Count                                 0.000001         0.000002            0.269           0.788
# L3.Avg. Customer Radius to Delivered (mins)         0.142370         0.063124            2.255           0.024
# L3.% Long Assignment Orders                         0.348020         1.195929            0.291           0.771
# L3.% HQ Orders                                      0.583194         0.535417            1.089           0.276
# L3.Avg. End To End (mins)                           0.000159         0.009084            0.018           0.986
# ==============================================================================================================
#
# Results for equation Bad Orders
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                            1682.549520      1498.638705            1.123           0.262
# L1.Gross CPO                                    43621.140774    123888.711416            0.352           0.725
# L1.Policy change 1                             -14492.627098      8654.589711           -1.675           0.094
# L1.Policy change 2                              -1567.104352      8576.095805           -0.183           0.855
# L1.Automation (%)                             -287211.314625    254519.249410           -1.128           0.259
# L1.Bad Orders                                      -0.740770         0.727512           -1.018           0.309
# L1.Undelivered Orders                              -0.183676         7.846079           -0.023           0.981
# L1.Restaurant Count                               -11.889239        12.920945           -0.920           0.357
# L1.Avg. Customer Radius to Delivered (mins)      7413.475962     36760.643992            0.202           0.840
# L1.% Long Assignment Orders                    130411.603343   1222971.174769            0.107           0.915
# L1.% HQ Orders                                -799675.922990    561894.413486           -1.423           0.155
# L1.Avg. End To End (mins)                       -4049.457839      9555.460436           -0.424           0.672
# L2.Gross CPO                                  -112136.155519    157300.901579           -0.713           0.476
# L2.Policy change 1                              -7969.835579     13548.571372           -0.588           0.556
# L2.Policy change 2                              14008.724601      8319.110085            1.684           0.092
# L2.Automation (%)                             -134858.913307    293686.976958           -0.459           0.646
# L2.Bad Orders                                      -0.513377         0.558648           -0.919           0.358
# L2.Undelivered Orders                              -2.547247         7.711676           -0.330           0.741
# L2.Restaurant Count                                -0.501787         2.884723           -0.174           0.862
# L2.Avg. Customer Radius to Delivered (mins)     73367.317027     39669.421374            1.849           0.064
# L2.% Long Assignment Orders                    790659.473749   1096371.313843            0.721           0.471
# L2.% HQ Orders                                -414554.584750    591828.597474           -0.700           0.484
# L2.Avg. End To End (mins)                       -3448.787346      9181.368837           -0.376           0.707
# L3.Gross CPO                                  -200042.961968    120066.850262           -1.666           0.096
# L3.Policy change 1                             -17263.171367     18611.396047           -0.928           0.354
# L3.Policy change 2                              10860.773089      9571.232098            1.135           0.256
# L3.Automation (%)                              -75660.746917    281893.541454           -0.268           0.788
# L3.Bad Orders                                       0.152672         0.506752            0.301           0.763
# L3.Undelivered Orders                              -7.515273         7.595891           -0.989           0.322
# L3.Restaurant Count                                 1.130921         2.175910            0.520           0.603
# L3.Avg. Customer Radius to Delivered (mins)     70351.468294     56732.112643            1.240           0.215
# L3.% Long Assignment Orders                   -157402.219887   1074827.033786           -0.146           0.884
# L3.% HQ Orders                                 576000.304436    481199.258838            1.197           0.231
# L3.Avg. End To End (mins)                        4868.292313      8163.990322            0.596           0.551
# ==============================================================================================================
#
# Results for equation Undelivered Orders
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                              47.067311        71.803162            0.656           0.512
# L1.Gross CPO                                     2222.652753      5935.787754            0.374           0.708
# L1.Policy change 1                                -62.637247       414.660925           -0.151           0.880
# L1.Policy change 2                               -412.658931       410.900104           -1.004           0.315
# L1.Automation (%)                               -5442.713364     12194.591633           -0.446           0.655
# L1.Bad Orders                                      -0.025649         0.034857           -0.736           0.462
# L1.Undelivered Orders                              -0.394085         0.375923           -1.048           0.294
# L1.Restaurant Count                                -0.505215         0.619072           -0.816           0.414
# L1.Avg. Customer Radius to Delivered (mins)       414.454068      1761.285414            0.235           0.814
# L1.% Long Assignment Orders                    -23378.753860     58595.308961           -0.399           0.690
# L1.% HQ Orders                                  -2740.121988     26921.629423           -0.102           0.919
# L1.Avg. End To End (mins)                         288.491742       457.823674            0.630           0.529
# L2.Gross CPO                                     4478.859803      7536.641188            0.594           0.552
# L2.Policy change 1                                -54.071058       649.142631           -0.083           0.934
# L2.Policy change 2                                221.263871       398.587339            0.555           0.579
# L2.Automation (%)                               -1944.785787     14071.205853           -0.138           0.890
# L2.Bad Orders                                      -0.039895         0.026766           -1.491           0.136
# L2.Undelivered Orders                              -0.116127         0.369484           -0.314           0.753
# L2.Restaurant Count                                 0.060923         0.138214            0.441           0.659
# L2.Avg. Customer Radius to Delivered (mins)      -647.186418      1900.651503           -0.341           0.733
# L2.% Long Assignment Orders                     12810.415858     52529.623916            0.244           0.807
# L2.% HQ Orders                                  -4620.629744     28355.843732           -0.163           0.871
# L2.Avg. End To End (mins)                         105.223698       439.900101            0.239           0.811
# L3.Gross CPO                                    -6379.017403      5752.673761           -1.109           0.267
# L3.Policy change 1                                180.017546       891.713986            0.202           0.840
# L3.Policy change 2                                227.883519       458.579330            0.497           0.619
# L3.Automation (%)                                 896.465567     13506.155743            0.066           0.947
# L3.Bad Orders                                       0.002877         0.024280            0.118           0.906
# L3.Undelivered Orders                              -0.160862         0.363936           -0.442           0.658
# L3.Restaurant Count                                 0.165195         0.104253            1.585           0.113
# L3.Avg. Customer Radius to Delivered (mins)      1312.631730      2718.163549            0.483           0.629
# L3.% Long Assignment Orders                    -29286.933514     51497.388837           -0.569           0.570
# L3.% HQ Orders                                 -11045.905587     23055.342452           -0.479           0.632
# L3.Avg. End To End (mins)                         124.499426       391.155201            0.318           0.750
# ==============================================================================================================
#
# Results for equation Restaurant Count
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                              20.596965        19.780392            1.041           0.298
# L1.Gross CPO                                      767.492177      1635.195542            0.469           0.639
# L1.Policy change 1                                 26.972141       114.231122            0.236           0.813
# L1.Policy change 2                                 33.992960       113.195088            0.300           0.764
# L1.Automation (%)                               -4184.869717      3359.375825           -1.246           0.213
# L1.Bad Orders                                       0.003349         0.009602            0.349           0.727
# L1.Undelivered Orders                              -0.016520         0.103560           -0.160           0.873
# L1.Restaurant Count                                 0.599417         0.170542            3.515           0.000
# L1.Avg. Customer Radius to Delivered (mins)      -144.287787       485.200310           -0.297           0.766
# L1.% Long Assignment Orders                      1474.611789     16141.882426            0.091           0.927
# L1.% HQ Orders                                   8722.300260      7416.391936            1.176           0.240
# L1.Avg. End To End (mins)                          18.877244       126.121631            0.150           0.881
# L2.Gross CPO                                     -184.542957      2076.199923           -0.089           0.929
# L2.Policy change 1                                -51.711389       178.826329           -0.289           0.772
# L2.Policy change 2                                189.995942       109.803158            1.730           0.084
# L2.Automation (%)                                2922.683641      3876.347006            0.754           0.451
# L2.Bad Orders                                      -0.005391         0.007374           -0.731           0.465
# L2.Undelivered Orders                               0.074581         0.101786            0.733           0.464
# L2.Restaurant Count                                 0.007186         0.038075            0.189           0.850
# L2.Avg. Customer Radius to Delivered (mins)      -442.051848       523.592991           -0.844           0.399
# L2.% Long Assignment Orders                       445.158763     14470.902674            0.031           0.975
# L2.% HQ Orders                                   2433.390002      7811.490437            0.312           0.755
# L2.Avg. End To End (mins)                          14.129916       121.184031            0.117           0.907
# L3.Gross CPO                                     2427.862309      1584.751154            1.532           0.126
# L3.Policy change 1                                -80.864761       245.650080           -0.329           0.742
# L3.Policy change 2                                121.108543       126.329799            0.959           0.338
# L3.Automation (%)                               -4318.055940      3720.686551           -1.161           0.246
# L3.Bad Orders                                      -0.001227         0.006689           -0.184           0.854
# L3.Undelivered Orders                              -0.009873         0.100257           -0.098           0.922
# L3.Restaurant Count                                 0.050527         0.028720            1.759           0.079
# L3.Avg. Customer Radius to Delivered (mins)      -695.600948       748.801861           -0.929           0.353
# L3.% Long Assignment Orders                      8765.051931     14186.541731            0.618           0.537
# L3.% HQ Orders                                  -2982.081446      6351.304119           -0.470           0.639
# L3.Avg. End To End (mins)                         -51.844611       107.755747           -0.481           0.630
# ==============================================================================================================
#
# Results for equation Avg. Customer Radius to Delivered (mins)
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                              -0.008098         0.006643           -1.219           0.223
# L1.Gross CPO                                        0.050606         0.549127            0.092           0.927
# L1.Policy change 1                                  0.005650         0.038361            0.147           0.883
# L1.Policy change 2                                 -0.012298         0.038013           -0.324           0.746
# L1.Automation (%)                                  -1.872944         1.128136           -1.660           0.097
# L1.Bad Orders                                      -0.000006         0.000003           -1.770           0.077
# L1.Undelivered Orders                              -0.000008         0.000035           -0.238           0.812
# L1.Restaurant Count                                 0.000000         0.000057            0.007           0.994
# L1.Avg. Customer Radius to Delivered (mins)        -0.505401         0.162939           -3.102           0.002
# L1.% Long Assignment Orders                        11.307017         5.420721            2.086           0.037
# L1.% HQ Orders                                      4.172608         2.490551            1.675           0.094
# L1.Avg. End To End (mins)                           0.027986         0.042354            0.661           0.509
# L2.Gross CPO                                        2.127653         0.697223            3.052           0.002
# L2.Policy change 1                                 -0.127323         0.060053           -2.120           0.034
# L2.Policy change 2                                  0.017470         0.036874            0.474           0.636
# L2.Automation (%)                                   2.923757         1.301744            2.246           0.025
# L2.Bad Orders                                      -0.000010         0.000002           -4.126           0.000
# L2.Undelivered Orders                               0.000062         0.000034            1.811           0.070
# L2.Restaurant Count                                 0.000021         0.000013            1.653           0.098
# L2.Avg. Customer Radius to Delivered (mins)        -0.587796         0.175831           -3.343           0.001
# L2.% Long Assignment Orders                         8.778424         4.859577            1.806           0.071
# L2.% HQ Orders                                      2.654622         2.623232            1.012           0.312
# L2.Avg. End To End (mins)                           0.004944         0.040696            0.121           0.903
# L3.Gross CPO                                        0.325934         0.532187            0.612           0.540
# L3.Policy change 1                                  0.114836         0.082494            1.392           0.164
# L3.Policy change 2                                 -0.028650         0.042424           -0.675           0.499
# L3.Automation (%)                                  -1.506933         1.249470           -1.206           0.228
# L3.Bad Orders                                      -0.000007         0.000002           -3.278           0.001
# L3.Undelivered Orders                              -0.000021         0.000034           -0.618           0.537
# L3.Restaurant Count                                 0.000018         0.000010            1.900           0.057
# L3.Avg. Customer Radius to Delivered (mins)        -0.685786         0.251460           -2.727           0.006
# L3.% Long Assignment Orders                         4.739813         4.764084            0.995           0.320
# L3.% HQ Orders                                     -5.248896         2.132877           -2.461           0.014
# L3.Avg. End To End (mins)                           0.027356         0.036186            0.756           0.450
# ==============================================================================================================
#
# Results for equation % Long Assignment Orders
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                               0.000570         0.001015            0.561           0.575
# L1.Gross CPO                                       -0.004973         0.083929           -0.059           0.953
# L1.Policy change 1                                 -0.002045         0.005863           -0.349           0.727
# L1.Policy change 2                                 -0.000428         0.005810           -0.074           0.941
# L1.Automation (%)                                  -0.218275         0.172425           -1.266           0.206
# L1.Bad Orders                                      -0.000000         0.000000           -0.040           0.968
# L1.Undelivered Orders                               0.000002         0.000005            0.403           0.687
# L1.Restaurant Count                                -0.000005         0.000009           -0.549           0.583
# L1.Avg. Customer Radius to Delivered (mins)        -0.007410         0.024904           -0.298           0.766
# L1.% Long Assignment Orders                         0.081733         0.828506            0.099           0.921
# L1.% HQ Orders                                     -0.605169         0.380657           -1.590           0.112
# L1.Avg. End To End (mins)                          -0.007262         0.006473           -1.122           0.262
# L2.Gross CPO                                       -0.105486         0.106564           -0.990           0.322
# L2.Policy change 1                                 -0.011343         0.009179           -1.236           0.217
# L2.Policy change 2                                  0.012933         0.005636            2.295           0.022
# L2.Automation (%)                                  -0.035858         0.198959           -0.180           0.857
# L2.Bad Orders                                      -0.000000         0.000000           -0.737           0.461
# L2.Undelivered Orders                              -0.000000         0.000005           -0.083           0.934
# L2.Restaurant Count                                -0.000001         0.000002           -0.305           0.760
# L2.Avg. Customer Radius to Delivered (mins)         0.051090         0.026874            1.901           0.057
# L2.% Long Assignment Orders                         0.585131         0.742740            0.788           0.431
# L2.% HQ Orders                                     -0.125724         0.400936           -0.314           0.754
# L2.Avg. End To End (mins)                          -0.001345         0.006220           -0.216           0.829
# L3.Gross CPO                                       -0.075236         0.081340           -0.925           0.355
# L3.Policy change 1                                 -0.018513         0.012608           -1.468           0.142
# L3.Policy change 2                                  0.005571         0.006484            0.859           0.390
# L3.Automation (%)                                  -0.093765         0.190970           -0.491           0.623
# L3.Bad Orders                                       0.000000         0.000000            0.299           0.765
# L3.Undelivered Orders                              -0.000004         0.000005           -0.718           0.473
# L3.Restaurant Count                                 0.000001         0.000001            0.653           0.514
# L3.Avg. Customer Radius to Delivered (mins)         0.034329         0.038433            0.893           0.372
# L3.% Long Assignment Orders                        -0.122610         0.728145           -0.168           0.866
# L3.% HQ Orders                                      0.309063         0.325990            0.948           0.343
# L3.Avg. End To End (mins)                           0.003152         0.005531            0.570           0.569
# ==============================================================================================================
#
# Results for equation % HQ Orders
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                              -0.000775         0.001009           -0.769           0.442
# L1.Gross CPO                                       -0.100292         0.083383           -1.203           0.229
# L1.Policy change 1                                  0.002284         0.005825            0.392           0.695
# L1.Policy change 2                                  0.000611         0.005772            0.106           0.916
# L1.Automation (%)                                   0.000635         0.171304            0.004           0.997
# L1.Bad Orders                                       0.000000         0.000000            0.108           0.914
# L1.Undelivered Orders                              -0.000007         0.000005           -1.350           0.177
# L1.Restaurant Count                                 0.000007         0.000009            0.794           0.427
# L1.Avg. Customer Radius to Delivered (mins)         0.038446         0.024742            1.554           0.120
# L1.% Long Assignment Orders                         0.542693         0.823118            0.659           0.510
# L1.% HQ Orders                                      0.621562         0.378182            1.644           0.100
# L1.Avg. End To End (mins)                           0.007374         0.006431            1.147           0.252
# L2.Gross CPO                                        0.166279         0.105871            1.571           0.116
# L2.Policy change 1                                  0.005770         0.009119            0.633           0.527
# L2.Policy change 2                                 -0.014073         0.005599           -2.513           0.012
# L2.Automation (%)                                   0.322333         0.197665            1.631           0.103
# L2.Bad Orders                                      -0.000000         0.000000           -0.012           0.991
# L2.Undelivered Orders                               0.000004         0.000005            0.773           0.440
# L2.Restaurant Count                                 0.000001         0.000002            0.274           0.784
# L2.Avg. Customer Radius to Delivered (mins)         0.000789         0.026699            0.030           0.976
# L2.% Long Assignment Orders                        -0.592925         0.737910           -0.804           0.422
# L2.% HQ Orders                                      0.270441         0.398329            0.679           0.497
# L2.Avg. End To End (mins)                           0.002103         0.006179            0.340           0.734
# L3.Gross CPO                                        0.081682         0.080811            1.011           0.312
# L3.Policy change 1                                  0.021184         0.012526            1.691           0.091
# L3.Policy change 2                                 -0.011054         0.006442           -1.716           0.086
# L3.Automation (%)                                  -0.007311         0.189728           -0.039           0.969
# L3.Bad Orders                                      -0.000000         0.000000           -0.640           0.522
# L3.Undelivered Orders                               0.000002         0.000005            0.300           0.764
# L3.Restaurant Count                                -0.000001         0.000001           -0.406           0.685
# L3.Avg. Customer Radius to Delivered (mins)        -0.050290         0.038183           -1.317           0.188
# L3.% Long Assignment Orders                         0.347476         0.723410            0.480           0.631
# L3.% HQ Orders                                     -0.737381         0.323870           -2.277           0.023
# L3.Avg. End To End (mins)                          -0.005277         0.005495           -0.960           0.337
# ==============================================================================================================
#
# Results for equation Avg. End To End (mins)
# ==============================================================================================================
#                                                  coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------------
# const                                               0.120439         0.155552            0.774           0.439
# L1.Gross CPO                                        0.611251        12.859110            0.048           0.962
# L1.Policy change 1                                 -0.113801         0.898309           -0.127           0.899
# L1.Policy change 2                                 -0.029877         0.890161           -0.034           0.973
# L1.Automation (%)                                 -24.592714        26.417992           -0.931           0.352
# L1.Bad Orders                                      -0.000031         0.000076           -0.416           0.677
# L1.Undelivered Orders                               0.000203         0.000814            0.249           0.804
# L1.Restaurant Count                                -0.001406         0.001341           -1.048           0.294
# L1.Avg. Customer Radius to Delivered (mins)        -0.147295         3.815595           -0.039           0.969
# L1.% Long Assignment Orders                        -3.348154       126.939095           -0.026           0.979
# L1.% HQ Orders                                    -74.439934        58.322199           -1.276           0.202
# L1.Avg. End To End (mins)                          -0.666234         0.991815           -0.672           0.502
# L2.Gross CPO                                      -11.460223        16.327150           -0.702           0.483
# L2.Policy change 1                                 -1.866669         1.406283           -1.327           0.184
# L2.Policy change 2                                  2.158800         0.863487            2.500           0.012
# L2.Automation (%)                                 -19.731188        30.483432           -0.647           0.517
# L2.Bad Orders                                      -0.000041         0.000058           -0.715           0.475
# L2.Undelivered Orders                              -0.000274         0.000800           -0.342           0.732
# L2.Restaurant Count                                 0.000062         0.000299            0.207           0.836
# L2.Avg. Customer Radius to Delivered (mins)         4.978992         4.117514            1.209           0.227
# L2.% Long Assignment Orders                        84.360189       113.798579            0.741           0.459
# L2.% HQ Orders                                    -28.469427        61.429237           -0.463           0.643
# L2.Avg. End To End (mins)                          -0.291907         0.952986           -0.306           0.759
# L3.Gross CPO                                      -10.839126        12.462417           -0.870           0.384
# L3.Policy change 1                                 -2.263213         1.931782           -1.172           0.241
# L3.Policy change 2                                  1.055431         0.993452            1.062           0.288
# L3.Automation (%)                                 -10.237229        29.259325           -0.350           0.726
# L3.Bad Orders                                       0.000002         0.000053            0.031           0.975
# L3.Undelivered Orders                              -0.000457         0.000788           -0.580           0.562
# L3.Restaurant Count                                 0.000200         0.000226            0.885           0.376
# L3.Avg. Customer Radius to Delivered (mins)         6.858968         5.888547            1.165           0.244
# L3.% Long Assignment Orders                        10.788878       111.562376            0.097           0.923
# L3.% HQ Orders                                     39.791097        49.946392            0.797           0.426
# L3.Avg. End To End (mins)                           0.256045         0.847387            0.302           0.763
# ==============================================================================================================
#
# Correlation matrix of residuals
#                                             Gross CPO  Policy change 1  Policy change 2  Automation (%)  Bad Orders  Undelivered Orders  Restaurant Count  Avg. Customer Radius to Delivered (mins)  % Long Assignment Orders  % HQ Orders  Avg. End To End (mins)
# Gross CPO                                    1.000000        -0.363294         0.087322       -0.122083    0.618403            0.439370         -0.348068                                  0.160637                  0.558413    -0.657541                0.577360
# Policy change 1                             -0.363294         1.000000        -0.054072        0.365350   -0.124555           -0.266211         -0.010916                                  0.248422                  0.019710     0.375281               -0.131612
# Policy change 2                              0.087322        -0.054072         1.000000        0.078335    0.399668            0.367186         -0.061639                                  0.188157                  0.361502    -0.067597                0.334383
# Automation (%)                              -0.122083         0.365350         0.078335        1.000000    0.403288           -0.189223          0.037247                                  0.273746                  0.438228    -0.201309                0.360582
# Bad Orders                                   0.618403        -0.124555         0.399668        0.403288    1.000000            0.580536         -0.077258                                  0.423652                  0.963820    -0.816448                0.952770
# Undelivered Orders                           0.439370        -0.266211         0.367186       -0.189223    0.580536            1.000000          0.114575                                  0.282425                  0.583506    -0.608474                0.666924
# Restaurant Count                            -0.348068        -0.010916        -0.061639        0.037247   -0.077258            0.114575          1.000000                                 -0.321618                 -0.145574    -0.032319               -0.022992
# Avg. Customer Radius to Delivered (mins)     0.160637         0.248422         0.188157        0.273746    0.423652            0.282425         -0.321618                                  1.000000                  0.474907    -0.265757                0.387366
# % Long Assignment Orders                     0.558413         0.019710         0.361502        0.438228    0.963820            0.583506         -0.145574                                  0.474907                  1.000000    -0.794756                0.958582
# % HQ Orders                                 -0.657541         0.375281        -0.067597       -0.201309   -0.816448           -0.608474         -0.032319                                 -0.265757                 -0.794756     1.000000               -0.857084
# Avg. End To End (mins)                       0.577360        -0.131612         0.334383        0.360582    0.952770            0.666924         -0.022992                                  0.387366                  0.958582    -0.857084                1.000000

# %% [markdown]
# ## 6. Extract driver impact via Impulse Response Functions (IRF)

# %% [markdown]
# IRF answers the question:
# “How does a shock (increase) in driver X affect Gross CPO over the next weeks?”

# %%
# Generate IRF object (example: 8-step horizon)
irf = var_model.irf(8)

# Extract IRF arrays
# irf.irfs shape = (steps+1, n_variables, n_variables)
irf_array = irf.irfs  
steps, k, _ = irf_array.shape

variables = ts_df_diff.columns.tolist()

# Create readable subplots
fig, axes = plt.subplots(nrows=k, ncols=1, figsize=(12, 3*k), sharex=True)

if k == 1:
    axes = [axes]  # handle single variable case

response_dict ={}
for i, ax in enumerate(axes):
    # IRF of "shock in Gross CPO" on variable i
    response = irf_array[:, i, variables.index('Gross CPO')] 
    response_dict[variables[i]]=response
    
    ax.plot(response, marker="o")
    ax.axhline(0, color='black', linewidth=1)
    ax.set_title(f"Response of {variables[i]} to a Shock in Gross CPO", fontsize=14)
    # ax.set_title(f"Impulse Response: Shock to Gross CPO → {variables[i]}", fontsize=14)
    ax.set_ylabel("Effect size", fontsize=12)
    ax.grid(alpha=0.3)

axes[-1].set_xlabel("Weeks after shock", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Choose which variables you want to plot
selected_vars = ['Policy change 1', 'Avg. End To End (mins)', 'Bad Orders', 'Undelivered Orders', 'Automation (%)']

selected_indices = [variables.index(v) for v in selected_vars]

fig, axes = plt.subplots(
    nrows=len(selected_indices),
    ncols=1,
    figsize=(12, 3 * len(selected_indices)),
    sharex=True
)

if len(selected_indices) == 1:
    axes = [axes]

for ax, resp_idx in zip(axes, selected_indices):

    # Shock is always Gross CPO
    shock_idx = variables.index('Gross CPO')

    # IRF array assumed shape: [time, response, shock]
    response = irf_array[:, resp_idx, shock_idx]
    
    response_dict[variables[resp_idx]] = response

    ax.plot(response, marker="o")
    ax.axhline(0, color='black', linewidth=1)
    
    ax.set_title(
        f"Response of {variables[resp_idx]} to a Shock in Gross CPO",
        
        fontsize=14
    )
    ax.set_ylabel("Effect size", fontsize=12)
    ax.grid(alpha=0.3)

axes[-1].set_xlabel("Weeks after shock", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# __Findings__:
#
# 1. Gross CPO → Policy Change 1
# * Policy Change 1 appears to be a reactive mechanism. When CPO spikes, the system quickly pulls back (negative values), possibly tightening rules or reinstating controls.
# * Later overshoot suggests temporary over-correction. This looks like a corrective operational policy cycle.
#
# 2. Gross CPO → Policy Change 2
# * A CPO increase leads to a reduction in Policy Change 2 metrics—suggesting this policy area may get “paused” or rolled back when costs increase, then slowly re-applied.
# * Indicates policy throttling when compensation spikes.

# %% [markdown]
# ## 7. Forecast Error Variance Decomposition (FEVD)

# %%
H = 8  # horizon
fevd = var_model.fevd(H)

variables = fevd.names
k = len(variables)

for i, var in enumerate(variables[1:]):
    
    contrib = fevd.decomp[i]        # shape (H, k)
    
    plt.figure(figsize=(10,5))
    
    for j in range(k):
        plt.plot(range(1, H+1), contrib[:, j], label=variables[j])
    
    plt.title(f"FEVD for {var}", fontsize=14)
    plt.xlabel("Weeks Ahead")
    plt.ylabel("Variance Explained")
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 7.1 Extract FEVD Driver Contributions (8-week horizon)

# %%
H = 8   # horizon used in your FEVD
fevd = var_model.fevd(H)

# driver names
variables = fevd.names

# FEVD for Gross CPO is index 0 (assuming Gross CPO is first in VAR model)
gross_cpo_index = 0

# FEVD matrix: shape (horizon, num_variables)
fevd_matrix = fevd.decomp[gross_cpo_index]   # returns horizon × drivers

# Take the final horizon (most stable variance decomposition)
final_fevd = fevd_matrix[-1]

# Build ranking table
ranking_df = pd.DataFrame({
    'Driver': variables[1:],
    'Variance_Explained_at_Horizon_8': final_fevd[1:]
})

ranking_df = ranking_df.sort_values(
    by='Variance_Explained_at_Horizon_8',
    ascending=False
).reset_index(drop=True)

ranking_df
# Out:
#                                      Driver  Variance_Explained_at_Horizon_8
# 0                           Policy change 1                         0.151793
# 1                    Avg. End To End (mins)                         0.109534
# 2                        Undelivered Orders                         0.075378
# 3                                Bad Orders                         0.072894
# 4                            Automation (%)                         0.072710
# 5  Avg. Customer Radius to Delivered (mins)                         0.043189
# 6                               % HQ Orders                         0.032191
# 7                           Policy change 2                         0.031741
# 8                  % Long Assignment Orders                         0.024229
# 9                          Restaurant Count                         0.018177

# %% [markdown]
# __Note :__
# - We use the FEVD plots for directional understanding, but we rely on the numeric extraction from the FEVD decomposition matrix to quantify driver importance.
# - The visual FEVD often under- or over-represents magnitude due to normalisation and axis scaling.
# - Therefore, the numeric FEVD contributions represent the true variance share explained by each driver.

# %% [markdown]
# ## 8. Forecast

# %%
forecast = var_model.forecast(ts_df_diff.values[-best_lag:], steps=8)
forecast_df = pd.DataFrame(forecast, columns=ts_df_diff.columns)
forecast_df
# Out:
#    Gross CPO  Policy change 1  Policy change 2  Automation (%)   Bad Orders  \
# 0   0.007393         0.244010        -0.031166       -0.007614  4759.773268
# 1  -0.004908        -0.154129        -0.020964        0.001841 -5359.149677
# 2   0.003598         0.140569         0.051254       -0.004349  3466.593189
# 3  -0.026569        -0.154474        -0.006409        0.008322 -3813.153424
# 4   0.009850         0.020250        -0.007646       -0.001036  -672.573575
# 5   0.004922         0.045385         0.008588        0.000785  6277.421019
# 6  -0.006215        -0.040578        -0.003326       -0.002944 -1170.765686
# 7  -0.002946         0.005051        -0.017566        0.004364  -986.773011
#
#    Undelivered Orders  Restaurant Count  \
# 0          903.435625         78.189877
# 1         -146.725869         43.671717
# 2         -247.050035         34.098494
# 3           95.313833         87.029702
# 4          -98.302390        -36.943993
# 5          194.472361        105.230805
# 6          -11.302487          5.209753
# 7          -36.762579         32.937318
#
#    Avg. Customer Radius to Delivered (mins)  % Long Assignment Orders  \
# 0                                  0.063053                 -0.003204
# 1                                  0.004291                 -0.000371
# 2                                 -0.043188                 -0.001430
# 3                                 -0.056479                  0.000298
# 4                                  0.005702                 -0.002129
# 5                                  0.001523                  0.004057
# 6                                  0.019986                 -0.000464
# 7                                 -0.019168                 -0.000775
#
#    % HQ Orders  Avg. End To End (mins)
# 0     0.005821               -0.191520
# 1    -0.003733               -0.004024
# 2     0.006063               -0.405991
# 3    -0.003514                0.063719
# 4    -0.002668               -0.106372
# 5    -0.006891                0.548847
# 6     0.002666               -0.206364
# 7     0.002212               -0.131515
